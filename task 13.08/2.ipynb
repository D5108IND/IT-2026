# %% [markdown]
# 1. Створити список напрямків, по яких ведеться аналіз
# 2. Створити словник із втратами, по яких ведеться аналіз.
# 3. Побудувати множину типів виявленої техніки на основі списку спостережень.
# 4. Вивести підрозділи, втрати яких перевищують 50 осіб

# %%
directions = ["Покровський", "Курахівський", "Оріхівський", "Купянський", "Лиманський"]
print (directions)
# Out:
# ['Покровський', 'Курахівський', 'Оріхівський', 'Купянський', 'Лиманський']

# %%
vtraty = {
    "Підрозділ 5106": 35,
    "Підрозділ 5107": 67,
    "Підрозділ 5108": 0,
    "Підрозділ 5109": 28
}

sumarni_vtraty = sum(vtraty.values())

print("Втрати підрозділів:")
print(vtraty)
print("Сумарні втрати:", sumarni_vtraty)
# Out:
# Втрати підрозділів:
# {'Підрозділ 5106': 35, 'Підрозділ 5107': 67, 'Підрозділ 5108': 0, 'Підрозділ 5109': 28}
# Сумарні втрати: 130

# %%
sposterezhennya = ["САУ", "Су-34", "САУ", "Буханка", "САУ", "Мотоцикл"]
typy_tekhniky = set(sposterezhennya)

print("Типи виявленої техніки:")
print(typy_tekhniky)
# Out:
# Типи виявленої техніки:
# {'Мотоцикл', 'САУ', 'Буханка', 'Су-34'}

# %%
print("Підрозділи з втратами понад 50 осіб:")

for pidrozdil, vtraty_kilkist in vtraty.items():
    if vtraty_kilkist > 50:
        print(pidrozdil, "-", vtraty_kilkist)
# Out:
# Підрозділи з втратами понад 50 осіб:
# Підрозділ Б - 67
# Підрозділ В - 52
