# %%
directions = ["Схід", "Південь", "Північ"]
print (directions)
# Out:
# ['Схід', 'Південь', 'Північ']

# %%
directions = ["Схід", "Південь", "Північ"]
directions.append("Захід")
print (directions)
# Out:
# ['Схід', 'Південь', 'Північ', 'Захід']

# %%
directions = ["Схід", "Південь", "Північ"]
directions.append("Захід")
print (directions)

losses_per_day = [30, 45, 25, 60]
losses_per_day.sort(reverse=True)
print(losses_per_day)
# Out:
# ['Схід', 'Південь', 'Північ', 'Захід']
# [60, 45, 30, 25]

# %%
losses_per_day[2] = 50
losses_per_day
# Out:
# [60, 45, 50, 25]

# %%
losses_per_day.clear()

# %%
losses_per_day
# Out:
# []

# %%
coordinates = (23.45, 54.32)

print(coordinates)
# Out:
# (23.45, 54.32)

# %%
coordinates.index(54.32)
# Out:
# 1

# %%
MyTuple = (1, 2, 2, 4, 2)

MyTuple.count(4)
# Out:
# 1

# %%
len(losses_per_day)
# Out:
# 0

# %%
for data in MyTuple:
    print(data)
# Out:
# 1
# 2
# 2
# 4
# 2

# %%
MyDict = {}
